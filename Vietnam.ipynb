# %% [markdown]
# # Capstone project

# %% [markdown]
# ## Business

# %% [markdown]
# We will find the best location to open a Italian restaurant in Vietnam.

# %% [markdown]
# ## Data

# %% [markdown]
# - We will base on the popularity of coffee shop to define if we should open it in that neighborhood
# - Position that is close to the center of the city which is district 1

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import folium
import requests

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /Users/buinhatquang/anaconda3/lib/python3.7/site-packages (4.3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
district = ["District 1", "District 2", "District 3","District 4"
            ,"District 7","Binh Thanh","Tan Binh","Binh Tan","Phu Nhuan", "Thu Duc"]
postal = [710000,711000,724000,728000,729000
          ,723000,721000,762000,725600,721400]
lat = [10.779320, 10.787182, 10.784265, 10.757808, 10.734065, 10.810574,10.801498, 
       10.765238, 10.799217,10.849422]
long = [106.700059, 106.749557, 106.684386, 106.701283, 106.721623, 106.709134,106.652643,
        106.603853, 106.680260,106.753664]
df = pd.DataFrame({"Neighborhood":district, "Postal code": postal, "Latitude": lat, "Longitude":long})
df
# Out:
#   Neighborhood  Postal code   Latitude   Longitude
# 0   District 1       710000  10.779320  106.700059
# 1   District 2       711000  10.787182  106.749557
# 2   District 3       724000  10.784265  106.684386
# 3   District 4       728000  10.757808  106.701283
# 4   District 7       729000  10.734065  106.721623
# 5   Binh Thanh       723000  10.810574  106.709134
# 6     Tan Binh       721000  10.801498  106.652643
# 7     Binh Tan       762000  10.765238  106.603853
# 8    Phu Nhuan       725600  10.799217  106.680260
# 9      Thu Duc       721400  10.849422  106.753664

# %%
lat = 10.762622
long = 106.660172
map_hcm = folium.Map(location=[lat,long], zoom_start=11)
for lat, lng, label in zip(df["Latitude"], df["Longitude"], df["Neighborhood"]):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color="blue",
        fill=True,
        fill_color='#3186cc',
        opacity=0.7,
        parse_html=False).add_to(map_hcm)
map_hcm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
from pandas.io.json import json_normalize

CLIENT_ID = '0E2W0K50NHZMGMNW3LP2NDJNZWBAMDHGGPTZA40IP0KGWAAJ' 
CLIENT_SECRET = 'NJSPIXE2GDYUT4YPSMXDF1HTWPR54YYYGG4U5HSTIDVN025D'
VERSION = '20180605'
district_lat = df.loc[0,"Latitude"]
district_lng = df.loc[0,"Longitude"]

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            100)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

df_1 = getNearbyVenues(df["Neighborhood"], df["Latitude"], df["Longitude"])
df_1
# Out:
# District 1
# District 2
# District 3
# District 4
# District 7
# Binh Thanh
# Tan Binh
# Binh Tan
# Phu Nhuan
# Thu Duc
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     District 1              10.779320              106.700059
# 1     District 1              10.779320              106.700059
# 2     District 1              10.779320              106.700059
# 3     District 1              10.779320              106.700059
# 4     District 1              10.779320              106.700059
# 5     District 1              10.779320              106.700059
# 6     District 1              10.779320              106.700059
# 7     District 1              10.779320              106.700059
# 8     District 1              10.779320              106.700059
# 9     District 1              10.779320              106.700059
# 10    District 1              10.779320              106.700059
# 11    District 1              10.779320              106.700059
# 12    District 1              10.779320              106.700059
# 13    District 1              10.779320              106.700059
# 14    District 1              10.779320              106.700059
# 15    District 1              10.779320              106.700059
# 16    District 1              10.779320              106.700059
# 17    District 1              10.779320              106.700059
# 18    District 1              10.779320              106.700059
# 19    District 1              10.779320              106.700059
# 20    District 1              10.779320              106.700059
# 21    District 1              10.779320              106.700059
# 22    District 1              10.779320              106.700059
# 23    District 1              10.779320              106.700059
# 24    District 1              10.779320              106.700059
# 25    District 1              10.779320              106.700059
# 26    District 1              10.779320              106.700059
# 27    District 1              10.779320              106.700059
# 28    District 1              10.779320              106.700059
# 29    District 1              10.779320              106.700059
# ..           ...                    ...                     ...
# 182     Tan Binh              10.801498              106.652643
# 183     Tan Binh              10.801498              106.652643
# 184     Tan Binh              10.801498              106.652643
# 185     Tan Binh              10.801498              106.652643
# 186     Tan Binh              10.801498              106.652643
# 187     Tan Binh              10.801498              106.652643
# 188     Tan Binh              10.801498              106.652643
# 189     Tan Binh              10.801498              106.652643
# 190     Tan Binh              10.801498              106.652643
# 191     Tan Binh              10.801498              106.652643
# 192     Tan Binh              10.801498              106.652643
# 193     Binh Tan              10.765238              106.603853
# 194     Binh Tan              10.765238              106.603853
# 195     Binh Tan              10.765238              106.603853
# 196    Phu Nhuan              10.799217              106.680260
# 197    Phu Nhuan              10.799217              106.680260
# 198    Phu Nhuan              10.799217              106.680260
# 199    Phu Nhuan              10.799217              106.680260
# 200    Phu Nhuan              10.799217              106.680260
# 201    Phu Nhuan              10.799217              106.680260
# 202    Phu Nhuan              10.799217              106.680260
# 203    Phu Nhuan              10.799217              106.680260
# 204    Phu Nhuan              10.799217              106.680260
# 205    Phu Nhuan              10.799217              106.680260
# 206    Phu Nhuan              10.799217              106.680260
# 207    Phu Nhuan              10.799217              106.680260
# 208      Thu Duc              10.849422              106.753664
# 209      Thu Duc              10.849422              106.753664
# 210      Thu Duc              10.849422              106.753664
# 211      Thu Duc              10.849422              106.753664
#
#                                                  Venue  Venue Latitude  \
# 0                           Đường Sách Nguyễn Văn Bình       10.780249
# 1                                          Cộng Cà Phê       10.777917
# 2                                       Pacey Cupcakes       10.780202
# 3                                           Propaganda       10.778913
# 4                              InterContinental Saigon       10.781261
# 5                Club Lounge @ InterContinental Saigon       10.780975
# 6                                    Starbucks Reserve       10.778961
# 7                                        Secret Garden       10.777422
# 8                                    Heart Of Darkness       10.779781
# 9                                            Starbucks       10.781078
# 10                                            Basilico       10.781411
# 11                  Bông Súng Vegetarian food - coffee       10.778088
# 12                              TCF The Coffee Factory       10.780012
# 13                                           Market 39       10.780618
# 14                                  TukTuk Thai Bistro       10.777389
# 15                                             Au Parc       10.778904
# 16                                      The Fish Sauce       10.781284
# 17                     Quan Chi Hoa Vietnamese Cuisine       10.779048
# 18                                       Chiyoda Sushi       10.778235
# 19                                   Park Hyatt Saigon       10.777574
# 20                                         Glow Skybar       10.776879
# 21                       Ganges Fine Dining Restaurant       10.778259
# 22     The Coffee Bean & Tea Leaf Hàn Thuyên - Pasteur       10.778586
# 23                     Nhà Hàng Ngon / Ngon Restaurant       10.777256
# 24                                               Opera       10.777190
# 25                              MGallery Hotel des Art       10.782382
# 26                        Social Club @ Hotel Des Arts       10.782372
# 27             My Spa - Traditional Vietnamese Massage       10.778890
# 28                                              Sky XX       10.781842
# 29                      Pasteur Street Brewing Company       10.775220
# ..                                                 ...             ...
# 182                              Sườn Cây Nướng & Beer       10.801032
# 183                              Lotte Cinema Cộng Hòa       10.800990
# 184                                 LotteMart Tân Bình       10.801121
# 185                                    Quen Restaurant       10.801143
# 186                  D'maris Premier Buffet Restaurant       10.801160
# 187                          Grand Palace Wedding Hall       10.804219
# 188                                      Cafe Ánh Hồng       10.800737
# 189                                Dìn Ký Grand Palace       10.803818
# 190                        San Bong Da mini Thanh Cong       10.805243
# 191                  Dalat Hasfarm Distribution Center       10.802594
# 192                           GongCha Nguyen Thai Binh       10.802663
# 193                              Coop Mart Khu Ten Lua       10.764542
# 194                                   Shop Đồ Bộ ĐU ĐỦ       10.764972
# 195                                        dienmay.com       10.762439
# 196                                          Café Trầm       10.796236
# 197                                   The Coffee House       10.797508
# 198                              Sườn cây nướng & beer       10.802166
# 199      California Fitness & Yoga Center - Cali Tower       10.801549
# 200                                       cafe hẻm 330       10.798621
# 201                                        3ackpackers       10.802986
# 202                   The Pizza Company Phan Xich Long       10.801545
# 203                                   Cháo Ếch Cay Cay       10.800923
# 204  FAHASA Phu Nhuan Bookstore (Nhà Sách Fahasa Ph...       10.795786
# 205                                           Cafe Nến       10.796066
# 206                              Bún chả cá Nguyễn Gia       10.801588
# 207                                   Bê Thui Sơn Ca 3       10.802288
# 208                          Dominos Pizza Kha Van can       10.846685
# 209                            Hủ Tiếu Bò Viên Xuân Ký       10.851161
# 210                            Bánh Flan Ngã 5 Thủ Đức       10.851877
# 211                                   Nhà Sách Sài Gòn       10.851736
#
#      Venue Longitude                 Venue Category
# 0         106.699404                      Bookstore
# 1         106.701266                           Café
# 2         106.700773                   Cupcake Shop
# 3         106.697893          Vietnamese Restaurant
# 4         106.700786                          Hotel
# 5         106.700968                      Hotel Bar
# 6         106.698185                    Coffee Shop
# 7         106.699926          Vietnamese Restaurant
# 8         106.702999                            Bar
# 9         106.700207                    Coffee Shop
# 10        106.701243             Italian Restaurant
# 11        106.699137  Vegetarian / Vegan Restaurant
# 12        106.700768                    Coffee Shop
# 13        106.700532                     Restaurant
# 14        106.700521                Thai Restaurant
# 15        106.697799      Middle Eastern Restaurant
# 16        106.699631               Asian Restaurant
# 17        106.703471          Vietnamese Restaurant
# 18        106.698370               Sushi Restaurant
# 19        106.703609                          Hotel
# 20        106.698330                            Bar
# 21        106.703087        North Indian Restaurant
# 22        106.697955                           Café
# 23        106.699594          Vietnamese Restaurant
# 24        106.703461             Italian Restaurant
# 25        106.697103                          Hotel
# 26        106.697303                      Hotel Bar
# 27        106.703693                 Massage Studio
# 28        106.700591                   Cocktail Bar
# 29        106.700894                        Brewery
# ..               ...                            ...
# 182       106.653790                      BBQ Joint
# 183       106.652754                      Multiplex
# 184       106.652878                    Supermarket
# 185       106.649805             Seafood Restaurant
# 186       106.653472                         Buffet
# 187       106.656121               Asian Restaurant
# 188       106.649611                           Café
# 189       106.655889          Vietnamese Restaurant
# 190       106.651327                   Soccer Field
# 191       106.656599                    Flower Shop
# 192       106.657020                           Café
# 193       106.604232                    Flea Market
# 194       106.602958                  Women's Store
# 195       106.604204              Electronics Store
# 196       106.678056                           Café
# 197       106.677602                    Coffee Shop
# 198       106.683711                      BBQ Joint
# 199       106.683371           Gym / Fitness Center
# 200       106.680836                           Café
# 201       106.681696                           Café
# 202       106.683276                    Pizza Place
# 203       106.683843          Vietnamese Restaurant
# 204       106.682161                      Bookstore
# 205       106.678305                    Coffee Shop
# 206       106.683170                     Food Court
# 207       106.682668          Vietnamese Restaurant
# 208       106.751388                    Pizza Place
# 209       106.754542                   Noodle House
# 210       106.754486                   Dessert Shop
# 211       106.755019                      Gift Shop
#
# [212 rows x 7 columns]

# %%
df_1["Venue Category"] = df_1["Venue Category"].replace("Café", "Coffee Shop")

# %%
hotspot = pd.get_dummies(df_1["Venue Category"], prefix="", prefix_sep="")
hotspot["Neighborhood"] = df_1["Neighborhood"]
hotspot_grouped = hotspot.groupby("Neighborhood").mean().reset_index()
hotspot_grouped
# Out:
#   Neighborhood  Argentinian Restaurant  Asian Restaurant  \
# 0     Binh Tan                 0.00000          0.000000
# 1   Binh Thanh                 0.00000          0.000000
# 2   District 1                 0.01087          0.032609
# 3   District 2                 0.00000          0.000000
# 4   District 3                 0.00000          0.055556
# 5   District 4                 0.00000          0.045455
# 6   District 7                 0.00000          0.000000
# 7    Phu Nhuan                 0.00000          0.000000
# 8     Tan Binh                 0.00000          0.071429
# 9      Thu Duc                 0.00000          0.000000
#
#    Australian Restaurant  BBQ Joint       Bar  Bed & Breakfast  Beer Garden  \
# 0                0.00000   0.000000  0.000000         0.000000      0.00000
# 1                0.00000   0.000000  0.000000         0.000000      0.00000
# 2                0.01087   0.021739  0.021739         0.000000      0.01087
# 3                0.00000   0.000000  0.000000         0.000000      0.00000
# 4                0.00000   0.027778  0.027778         0.000000      0.00000
# 5                0.00000   0.045455  0.000000         0.000000      0.00000
# 6                0.00000   0.071429  0.000000         0.071429      0.00000
# 7                0.00000   0.083333  0.000000         0.000000      0.00000
# 8                0.00000   0.071429  0.000000         0.000000      0.00000
# 9                0.00000   0.000000  0.000000         0.000000      0.00000
#
#    Bookstore  Breakfast Spot  ...       Spa  Supermarket  Sushi Restaurant  \
# 0   0.000000        0.000000  ...  0.000000     0.000000          0.000000
# 1   0.000000        0.125000  ...  0.000000     0.000000          0.000000
# 2   0.010870        0.000000  ...  0.000000     0.000000          0.010870
# 3   0.000000        0.000000  ...  0.000000     0.000000          0.000000
# 4   0.000000        0.027778  ...  0.027778     0.000000          0.000000
# 5   0.000000        0.000000  ...  0.000000     0.000000          0.000000
# 6   0.000000        0.000000  ...  0.000000     0.000000          0.071429
# 7   0.083333        0.000000  ...  0.000000     0.000000          0.000000
# 8   0.000000        0.000000  ...  0.000000     0.071429          0.071429
# 9   0.000000        0.000000  ...  0.000000     0.000000          0.000000
#
#    Tea Room  Thai Restaurant  Theater  Vegetarian / Vegan Restaurant  \
# 0   0.00000         0.000000  0.00000                       0.000000
# 1   0.00000         0.000000  0.00000                       0.000000
# 2   0.01087         0.021739  0.01087                       0.010870
# 3   0.00000         0.000000  0.00000                       0.000000
# 4   0.00000         0.000000  0.00000                       0.000000
# 5   0.00000         0.000000  0.00000                       0.045455
# 6   0.00000         0.000000  0.00000                       0.000000
# 7   0.00000         0.000000  0.00000                       0.000000
# 8   0.00000         0.000000  0.00000                       0.000000
# 9   0.00000         0.000000  0.00000                       0.000000
#
#    Vietnamese Restaurant  Whisky Bar  Women's Store
# 0               0.000000     0.00000       0.333333
# 1               0.125000     0.00000       0.000000
# 2               0.065217     0.01087       0.000000
# 3               0.428571     0.00000       0.000000
# 4               0.277778     0.00000       0.000000
# 5               0.045455     0.00000       0.000000
# 6               0.285714     0.00000       0.000000
# 7               0.166667     0.00000       0.000000
# 8               0.142857     0.00000       0.000000
# 9               0.000000     0.00000       0.000000
#
# [10 rows x 70 columns]

# %%
cols = ["Neighborhood"]
indicators = ["st", "nd", "rd"]

for x in range(0, 15):
    if x < 3:
        cols.append("The {}{} famous".format(x+1, indicators[x]))
    else:
        cols.append("The {}th famous".format(x+1))

hotspot_rank = pd.DataFrame(columns=cols)
hotspot_rank["Neighborhood"] = hotspot_grouped["Neighborhood"]
for x in range(len(hotspot_grouped)):
    hotspot_rank.iloc[x, 1:] = hotspot_grouped.iloc[x,1:].sort_values(ascending=False).iloc[0:15].index
hotspot_rank
# Out:
#   Neighborhood         The 1st famous         The 2nd famous  \
# 0     Binh Tan          Women's Store            Flea Market
# 1   Binh Thanh            Coffee Shop  Vietnamese Restaurant
# 2   District 1            Coffee Shop  Vietnamese Restaurant
# 3   District 2  Vietnamese Restaurant            Snack Place
# 4   District 3  Vietnamese Restaurant            Coffee Shop
# 5   District 4     Seafood Restaurant            Coffee Shop
# 6   District 7  Vietnamese Restaurant            Flea Market
# 7    Phu Nhuan            Coffee Shop  Vietnamese Restaurant
# 8     Tan Binh  Vietnamese Restaurant            Coffee Shop
# 9      Thu Duc            Pizza Place              Gift Shop
#
#          The 3rd famous      The 4th famous        The 5th famous  \
# 0     Electronics Store        Cupcake Shop          Dessert Shop
# 1          Dessert Shop          Food Truck        Breakfast Spot
# 2                 Hotel      Massage Studio    Italian Restaurant
# 3      Business Service         Bus Station            Restaurant
# 4     French Restaurant  Seafood Restaurant      Asian Restaurant
# 5           Snack Place   Korean Restaurant            Kids Store
# 6           Coffee Shop           BBQ Joint  Gym / Fitness Center
# 7           Pizza Place           Bookstore            Food Court
# 8  Gym / Fitness Center         Supermarket                Buffet
# 9          Noodle House        Dessert Shop  Fast Food Restaurant
#
#          The 6th famous               The 7th famous  \
# 0   Dumpling Restaurant  Eastern European Restaurant
# 1           Flea Market                 Cupcake Shop
# 2      Asian Restaurant                    Hotel Bar
# 3         Women's Store                 Dessert Shop
# 4             Rock Club                          Bar
# 5           Pizza Place          Japanese Restaurant
# 6      Sushi Restaurant              Bed & Breakfast
# 7  Gym / Fitness Center                    BBQ Joint
# 8           Flower Shop                 Soccer Field
# 9          Cupcake Shop          Dumpling Restaurant
#
#                 The 8th famous                            The 9th famous  \
# 0         Fast Food Restaurant                               Flower Shop
# 1          Dumpling Restaurant               Eastern European Restaurant
# 2            French Restaurant                       Japanese Restaurant
# 3          Dumpling Restaurant               Eastern European Restaurant
# 4                 Noodle House                                       Spa
# 5                      Brewery                        Mexican Restaurant
# 6          Japanese Restaurant  Residential Building (Apartment / Condo)
# 7                          Bar                              Cupcake Shop
# 8           Seafood Restaurant                          Sushi Restaurant
# 9  Eastern European Restaurant                         Electronics Store
#
#            The 10th famous       The 11th famous    The 12th famous  \
# 0                Hotel Bar                  Food         Food Court
# 1        Electronics Store  Fast Food Restaurant      Women's Store
# 2                   Lounge  Fast Food Restaurant  Hotpot Restaurant
# 3        Electronics Store  Fast Food Restaurant  Convenience Store
# 4           Breakfast Spot          Cupcake Shop             Lounge
# 5               Food Court                  Food          BBQ Joint
# 6  Scandinavian Restaurant     Electronics Store       Dessert Shop
# 7                Gift Shop     French Restaurant         Food Truck
# 8                BBQ Joint      Asian Restaurant          Multiplex
# 9              Flea Market           Coffee Shop        Flower Shop
#
#         The 13th famous              The 14th famous  \
# 0            Food Truck            French Restaurant
# 1     Convenience Store                         Food
# 2            Restaurant                      Brewery
# 3           Flea Market                  Flower Shop
# 4             BBQ Joint                    Juice Bar
# 5  Gym / Fitness Center             Asian Restaurant
# 6   Dumpling Restaurant  Eastern European Restaurant
# 7      Asian Restaurant                         Food
# 8            Food Court                   Food Truck
# 9                  Food                   Food Court
#
#                  The 15th famous
# 0                      Gift Shop
# 1                     Food Court
# 2                Thai Restaurant
# 3                           Food
# 4              Electronics Store
# 5  Vegetarian / Vegan Restaurant
# 6                  Women's Store
# 7                    Flower Shop
# 8                           Food
# 9                     Food Truck

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
sil = []
kmax = 5

# dissimilarity would not be defined for a single cluster, thus, minimum number of clusters should be 2
for k in range(2, kmax+1):
    kmeans = KMeans(n_clusters = k,random_state=0).fit(hotspot_grouped.drop(["Neighborhood"], axis=1))
    labels = kmeans.labels_
    sil.append(silhouette_score(hotspot_grouped.drop(["Neighborhood"], axis=1), labels, metric = 'euclidean'))
sil
# Out:
# [0.31622311484706256,
#  0.2824207275921604,
#  0.1620339123365619,
#  0.14617623957195267]

# %%
kmean = KMeans(init="k-means++", n_clusters=3, random_state=0).fit(hotspot_grouped.drop(["Neighborhood"], axis=1))
cluster = pd.DataFrame({"Cluster":kmean.labels_})

# %%
neighbor_list = []
for x in hotspot_rank.Neighborhood:
    neighbor_list.append(x)
latlng = df.set_index ("Neighborhood").loc[neighbor_list, ["Latitude", "Longitude"]].reset_index().drop(["Neighborhood"], axis=1)
vn_merged = pd.concat([cluster, hotspot_rank, latlng], axis=1).set_index("Neighborhood").reset_index()
vn_merged
# Out:
#   Neighborhood  Cluster         The 1st famous         The 2nd famous  \
# 0     Binh Tan        1          Women's Store            Flea Market
# 1   Binh Thanh        0            Coffee Shop  Vietnamese Restaurant
# 2   District 1        0            Coffee Shop  Vietnamese Restaurant
# 3   District 2        0  Vietnamese Restaurant            Snack Place
# 4   District 3        0  Vietnamese Restaurant            Coffee Shop
# 5   District 4        0     Seafood Restaurant            Coffee Shop
# 6   District 7        0  Vietnamese Restaurant            Flea Market
# 7    Phu Nhuan        0            Coffee Shop  Vietnamese Restaurant
# 8     Tan Binh        0  Vietnamese Restaurant            Coffee Shop
# 9      Thu Duc        2            Pizza Place              Gift Shop
#
#          The 3rd famous      The 4th famous        The 5th famous  \
# 0     Electronics Store        Cupcake Shop          Dessert Shop
# 1          Dessert Shop          Food Truck        Breakfast Spot
# 2                 Hotel      Massage Studio    Italian Restaurant
# 3      Business Service         Bus Station            Restaurant
# 4     French Restaurant  Seafood Restaurant      Asian Restaurant
# 5           Snack Place   Korean Restaurant            Kids Store
# 6           Coffee Shop           BBQ Joint  Gym / Fitness Center
# 7           Pizza Place           Bookstore            Food Court
# 8  Gym / Fitness Center         Supermarket                Buffet
# 9          Noodle House        Dessert Shop  Fast Food Restaurant
#
#          The 6th famous               The 7th famous  \
# 0   Dumpling Restaurant  Eastern European Restaurant
# 1           Flea Market                 Cupcake Shop
# 2      Asian Restaurant                    Hotel Bar
# 3         Women's Store                 Dessert Shop
# 4             Rock Club                          Bar
# 5           Pizza Place          Japanese Restaurant
# 6      Sushi Restaurant              Bed & Breakfast
# 7  Gym / Fitness Center                    BBQ Joint
# 8           Flower Shop                 Soccer Field
# 9          Cupcake Shop          Dumpling Restaurant
#
#                 The 8th famous                            The 9th famous  \
# 0         Fast Food Restaurant                               Flower Shop
# 1          Dumpling Restaurant               Eastern European Restaurant
# 2            French Restaurant                       Japanese Restaurant
# 3          Dumpling Restaurant               Eastern European Restaurant
# 4                 Noodle House                                       Spa
# 5                      Brewery                        Mexican Restaurant
# 6          Japanese Restaurant  Residential Building (Apartment / Condo)
# 7                          Bar                              Cupcake Shop
# 8           Seafood Restaurant                          Sushi Restaurant
# 9  Eastern European Restaurant                         Electronics Store
#
#            The 10th famous       The 11th famous    The 12th famous  \
# 0                Hotel Bar                  Food         Food Court
# 1        Electronics Store  Fast Food Restaurant      Women's Store
# 2                   Lounge  Fast Food Restaurant  Hotpot Restaurant
# 3        Electronics Store  Fast Food Restaurant  Convenience Store
# 4           Breakfast Spot          Cupcake Shop             Lounge
# 5               Food Court                  Food          BBQ Joint
# 6  Scandinavian Restaurant     Electronics Store       Dessert Shop
# 7                Gift Shop     French Restaurant         Food Truck
# 8                BBQ Joint      Asian Restaurant          Multiplex
# 9              Flea Market           Coffee Shop        Flower Shop
#
#         The 13th famous              The 14th famous  \
# 0            Food Truck            French Restaurant
# 1     Convenience Store                         Food
# 2            Restaurant                      Brewery
# 3           Flea Market                  Flower Shop
# 4             BBQ Joint                    Juice Bar
# 5  Gym / Fitness Center             Asian Restaurant
# 6   Dumpling Restaurant  Eastern European Restaurant
# 7      Asian Restaurant                         Food
# 8            Food Court                   Food Truck
# 9                  Food                   Food Court
#
#                  The 15th famous   Latitude   Longitude
# 0                      Gift Shop  10.765238  106.603853
# 1                     Food Court  10.810574  106.709134
# 2                Thai Restaurant  10.779320  106.700059
# 3                           Food  10.787182  106.749557
# 4              Electronics Store  10.784265  106.684386
# 5  Vegetarian / Vegan Restaurant  10.757808  106.701283
# 6                  Women's Store  10.734065  106.721623
# 7                    Flower Shop  10.799217  106.680260
# 8                           Food  10.801498  106.652643
# 9                     Food Truck  10.849422  106.753664

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors


# create map
map_clusters = folium.Map(location=[lat, long], zoom_start=11)

# set color scheme for the clusters
x = np.arange(5)
ys = [i + x + (i*x)**2 for i in range(5)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(vn_merged['Latitude'], vn_merged['Longitude'], vn_merged['Neighborhood'], vn_merged['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_1[df_1["Neighborhood"]=="District 3"]["Venue Category"].value_counts().to_frame()
# Out:
#                        Venue Category
# Vietnamese Restaurant              10
# Coffee Shop                         9
# French Restaurant                   3
# Seafood Restaurant                  3
# Asian Restaurant                    2
# Breakfast Spot                      1
# Cupcake Shop                        1
# Noodle House                        1
# Bar                                 1
# Juice Bar                           1
# Lounge                              1
# Spa                                 1
# Rock Club                           1
# BBQ Joint                           1

# %%
df_1[df_1["Neighborhood"]=="District 1"]["Venue Category"].value_counts().to_frame()
# Out:
#                                Venue Category
# Coffee Shop                                21
# Hotel                                       6
# Vietnamese Restaurant                       6
# Massage Studio                              4
# Hotel Bar                                   3
# French Restaurant                           3
# Asian Restaurant                            3
# Italian Restaurant                          3
# BBQ Joint                                   2
# Thai Restaurant                             2
# Brewery                                     2
# Restaurant                                  2
# Hotpot Restaurant                           2
# Lounge                                      2
# Fast Food Restaurant                        2
# Bar                                         2
# Japanese Restaurant                         2
# Theater                                     1
# Burger Joint                                1
# Juice Bar                                   1
# Argentinian Restaurant                      1
# Tea Room                                    1
# North Indian Restaurant                     1
# Bookstore                                   1
# Buffet                                      1
# Museum                                      1
# Ice Cream Shop                              1
# Vegetarian / Vegan Restaurant               1
# Cocktail Bar                                1
# Clothing Store                              1
# Australian Restaurant                       1
# Park                                        1
# Eastern European Restaurant                 1
# Whisky Bar                                  1
# Gym / Fitness Center                        1
# Opera House                                 1
# Flower Shop                                 1
# Dumpling Restaurant                         1
# Middle Eastern Restaurant                   1
# Cupcake Shop                                1
# Beer Garden                                 1
# Sushi Restaurant                            1

# %% [markdown]
# ## Conclusion

# %% [markdown]
# As you can see the 3 districts that is close to the center are district 1,3,4. In the top 5 famous venues in
# district 3, 4 of them are different culture restaurants. It seem like people around this area love restaurant
# and especially different culture restaurants. However, there are no Italian restaurant here yet, hence there are
# less competetor. As the result, we should open the restaurant somewhere in district 3 because it is close to the
# center of the city, people love different culture restaurant, and there are no Italian restaurant here. A reason for not open it in district 1 is because it is the center of the city so the rent will be expensive, plus there are
# 3 Italian restaurants there so it is very competitive.
